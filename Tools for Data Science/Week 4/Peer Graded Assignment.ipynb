# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Matheus Alexandre**
#
# Data Scientist

# %% [markdown]
# *I'm interested in data science because it can provide insights to the logistics industry on how to improve their entire supply chain.*

# %% [markdown]
# ### The cell below should print my name, followed by my desired occupation.

# %%
print('Matheus Alexandre\nData Scientist')
# Out:
# Matheus Alexandre
# Data Scientist

# %% [markdown]
# * Matheus Alexandre
# * Data Scientist
#
# ---
#
# > If you wish to make an apple pie from scratch, you must first invent the universe.
# ― Carl Sagan, Cosmos
